# %%
from utils import *
from constants import *

# %%
build_dbs()
# Out:
# DB Already Exist
# /home/Assignment/01_data_pipeline/scripts
# 'DB Exist'

# %%
cnx = sqlite3.connect(DB_PATH + DB_FILE_NAME)
df = pd.read_sql(f"SELECT name FROM sqlite_master WHERE type='table'", cnx)
print(df.shape)
df.head(16)
# Out:
# (3, 1)
#                            name
# 0                   loaded_data
# 1              city_tier_mapped
# 2  categorical_variables_mapped

# %%
load_data_into_db()
# Out:
# 'Writing to DataBase loaded_data Done or Data Already was in Table. Check Logs.'

# %%
df = pd.read_sql(f"SELECT name FROM sqlite_master WHERE type='table'", cnx)
print(df.shape)
df.head(16)
# Out:
# (3, 1)
#                            name
# 0              city_tier_mapped
# 1  categorical_variables_mapped
# 2                   loaded_data

# %%
df = pd.read_sql(f"SELECT * FROM loaded_data", cnx)
print(df.shape)
df.head(5)
# Out:
# (240000, 46)
#    index         created_date city_mapped first_platform_c first_utm_medium_c  \
# 0      0  2021-08-13 10:44:09      mumbai           Level0             Level0
# 1      1  2021-11-04 06:34:10         ncr           Level1             Level1
# 2      2  2021-07-29 14:01:00      meerut           Level0             Level2
# 3      3  2021-12-01 13:21:54         ncr           Level1             Level3
# 4      4  2021-12-10 07:22:51   ahmedabad           Level2             Level2
#
#   first_utm_source_c  total_leads_droppped  referred_lead  \
# 0             Level0                   1.0            0.0
# 1             Level1                   1.0            0.0
# 2             Level2                   2.0            0.0
# 3             Level3                   1.0            0.0
# 4             Level2                   1.0            0.0
#
#   1_on_1_industry_mentorship  call_us_button_clicked  ...  \
# 0                       None                     NaN  ...
# ...

# %%
map_city_tier()
# Out:
# 'Writing to DataBase city_tier_mapped Done or Data Already was in Table. Check Logs.'

# %%
df = pd.read_sql(f"SELECT name FROM sqlite_master WHERE type='table'", cnx)
print(df.shape)
df.head(16)
# Out:
# (3, 1)
#                            name
# 0  categorical_variables_mapped
# 1                   loaded_data
# 2              city_tier_mapped

# %%
df = pd.read_sql(f"SELECT * FROM city_tier_mapped", cnx)
print(df.shape)
df.head(5)
# Out:
# (240000, 46)
#    index         created_date first_platform_c first_utm_medium_c  \
# 0      0  2021-08-13 10:44:09           Level0             Level0
# 1      1  2021-11-04 06:34:10           Level1             Level1
# 2      2  2021-07-29 14:01:00           Level0             Level2
# 3      3  2021-12-01 13:21:54           Level1             Level3
# 4      4  2021-12-10 07:22:51           Level2             Level2
#
#   first_utm_source_c  total_leads_droppped  referred_lead  \
# 0             Level0                   1.0            0.0
# 1             Level1                   1.0            0.0
# 2             Level2                   2.0            0.0
# 3             Level3                   1.0            0.0
# 4             Level2                   1.0            0.0
#
#   1_on_1_industry_mentorship  call_us_button_clicked  career_assistance  ...  \
# 0                       None                     NaN                NaN  ...
# ...

# %%
map_categorical_vars()
# Out:
# /home/Assignment/01_data_pipeline/scripts/utils.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['first_platform_c'] = "others"
# /home/Assignment/01_data_pipeline/scripts/utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['first_utm_medium_c'] = "others"
# /home/Assignment/01_data_pipeline/scripts/utils.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# ...

# %%
df = pd.read_sql(f"SELECT name FROM sqlite_master WHERE type='table'", cnx)
print(df.shape)
df.head(16)
# Out:
# (3, 1)
#                            name
# 0                   loaded_data
# 1              city_tier_mapped
# 2  categorical_variables_mapped

# %%
df = pd.read_sql(f"SELECT * FROM categorical_variables_mapped", cnx)
print(df.shape)
df.head(5)
# Out:
# (240000, 46)
#    index         created_date first_platform_c first_utm_medium_c  \
# 0     11  2021-07-23 15:40:25           others             others
# 1     26  2021-09-02 17:22:29           others             others
# 2     28  2021-08-14 18:19:23           others             others
# 3     43  2022-01-31 12:05:08           others             others
# 4     46  2021-09-17 18:17:26           others             others
#
#   first_utm_source_c  total_leads_droppped  referred_lead  \
# 0             others                   1.0            0.0
# 1             others                   1.0            0.0
# 2             others                   1.0            0.0
# 3             others                   1.0            0.0
# 4             others                   1.0            0.0
#
#   1_on_1_industry_mentorship  call_us_button_clicked  career_assistance  ...  \
# 0                       None                     NaN                NaN  ...
# ...

# %%
df['app_complete_flag']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 239995    1
# 239996    1
# 239997    1
# 239998    1
# 239999    1
# Name: app_complete_flag, Length: 240000, dtype: int64

# %%
interactions_mapping()
# Out:
# 'Writing to DataBase- interactions_mapped Done . Check Logs.'

# %%
df = pd.read_sql(f"SELECT name FROM sqlite_master WHERE type='table'", cnx)
print(df.shape)
df.head(16)
# Out:
# (4, 1)
#                            name
# 0                   loaded_data
# 1              city_tier_mapped
# 2  categorical_variables_mapped
# 3           interactions_mapped

# %%
df = pd.read_sql(f"SELECT * FROM interactions_mapped", cnx)
print(df.shape)
df.head(5)
# Out:
# (2, 7)
#    index  app_complete_flag  assistance_interaction  career_interaction  \
# 0      0                  0                   151.0                95.0
# 1      1                  1                   173.0               108.0
#
#    payment_interaction  social_interaction  syllabus_interaction
# 0               1403.0                59.0                4486.0
# 1               3419.0                11.0                8037.0
